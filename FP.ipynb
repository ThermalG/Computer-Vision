# %% [markdown]
# <center><h1>McGill University ECSE 415 Introduction to Computer Vision</h1>
# <h2>Final Project </h2>
# Alex Wei 260981800<br>
# Zhanyue Zhang 260944809</center>
#
# ## *¡README!*
# 1. The assignment was develpoed in IntelliJ IDEA 2023.2.5, Python 3.11.6. Should you run in a different environment like Google Colab, please first ensure you make appropriate adaptation to the code.
#
# &nbsp;
# ## Version History
# **v0.1 2/11/2023 Initial submission**
#
# &nbsp;
# ## I -

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt


PATH = './Data/'    # change to your own path to apply globally

# %% [markdown]
# &nbsp;
# ## References
# 1.
